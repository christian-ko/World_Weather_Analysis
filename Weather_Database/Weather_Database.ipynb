# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | anchorage
# Processing Record 2 of Set 1 | seoul
# Processing Record 3 of Set 1 | ullal
# Processing Record 4 of Set 1 | port moresby
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | rio gallegos
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | chimore
# Processing Record 11 of Set 1 | kaitangata
# Processing Record 12 of Set 1 | manama
# Processing Record 13 of Set 1 | ambilobe
# Processing Record 14 of Set 1 | blagoyevo
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | baturaja
# Processing Record 17 of Set 1 | klaksvik
# Processing Record 18 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 1 | rusape
# Processing Record 20 of Set 1 | tuatapere
# Processing Record 21 of Set 1 | kavieng
# Processing Record 22 of Set 1 | mahebourg
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | lakes entrance
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | olafsvik
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | cayenne
# Processing Record 30 of Set 1 | gat
# Processing Record 31 of Set 1 | stornoway
# Processing Record 32 of Set 1 | kruisfontein
# Processing Record 33 of Set 1 | fortuna
# Processing Record 34 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 1 | tessalit
# Processing Record 36 of Set 1 | pingzhuang
# Processing Record 37 of Set 1 | galle
# Processing Record 38 of Set 1 | brae
# Processing Record 39 of Set 1 | komsomolskiy
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 1 | tostamaa
# City not found. Skipping...
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | lagoa
# Processing Record 48 of Set 1 | alice springs
# Processing Record 49 of Set 1 | laguna
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | progreso
# Processing Record 2 of Set 2 | napasar
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | sokoni
# Processing Record 6 of Set 2 | rawson
# Processing Record 7 of Set 2 | wladyslawowo
# Processing Record 8 of Set 2 | waterloo
# Processing Record 9 of Set 2 | kahului
# Processing Record 10 of Set 2 | the valley
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | bismarck
# Processing Record 13 of Set 2 | lima
# Processing Record 14 of Set 2 | banjarmasin
# Processing Record 15 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 2 | belmonte
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | raisinghnagar
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | noumea
# Processing Record 24 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | rockport
# Processing Record 30 of Set 2 | palmer
# Processing Record 31 of Set 2 | severo-kurilsk
# Processing Record 32 of Set 2 | vila franca do campo
# Processing Record 33 of Set 2 | mehamn
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | talnakh
# Processing Record 37 of Set 2 | cuamba
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 2 | greenville
# Processing Record 41 of Set 2 | maraa
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | bengkulu
# Processing Record 44 of Set 2 | kargat
# Processing Record 45 of Set 2 | bilma
# Processing Record 46 of Set 2 | bilokurakyne
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | rio tuba
# Processing Record 49 of Set 2 | butaritari
# Processing Record 50 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 3 | manokwari
# Processing Record 2 of Set 3 | praia
# Processing Record 3 of Set 3 | alofi
# Processing Record 4 of Set 3 | utena
# Processing Record 5 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 3 | grand gaube
# Processing Record 7 of Set 3 | kamenka
# Processing Record 8 of Set 3 | puerto quijarro
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | karpathos
# Processing Record 11 of Set 3 | pisco
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | lukoyanov
# Processing Record 14 of Set 3 | maarianhamina
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | saint-louis
# Processing Record 17 of Set 3 | buchanan
# Processing Record 18 of Set 3 | naters
# Processing Record 19 of Set 3 | rocha
# Processing Record 20 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 3 | isla mujeres
# Processing Record 22 of Set 3 | upernavik
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | san policarpo
# Processing Record 25 of Set 3 | half moon bay
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | saint anthony
# Processing Record 28 of Set 3 | aklavik
# Processing Record 29 of Set 3 | santa barbara
# Processing Record 30 of Set 3 | bambanglipuro
# Processing Record 31 of Set 3 | luena
# Processing Record 32 of Set 3 | belaya gora
# Processing Record 33 of Set 3 | mount gambier
# Processing Record 34 of Set 3 | nenjiang
# Processing Record 35 of Set 3 | broken hill
# Processing Record 36 of Set 3 | quang ngai
# Processing Record 37 of Set 3 | shingu
# Processing Record 38 of Set 3 | kaeo
# Processing Record 39 of Set 3 | wagar
# Processing Record 40 of Set 3 | mangrol
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 3 | hermanus
# Processing Record 46 of Set 3 | camacupa
# Processing Record 47 of Set 3 | taloda
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | tilichiki
# Processing Record 50 of Set 3 | bhuj
# Processing Record 1 of Set 4 | gachala
# Processing Record 2 of Set 4 | carutapera
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | vostok
# Processing Record 5 of Set 4 | hornepayne
# Processing Record 6 of Set 4 | kjollefjord
# Processing Record 7 of Set 4 | yenagoa
# Processing Record 8 of Set 4 | tucuman
# Processing Record 9 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 4 | constitucion
# Processing Record 11 of Set 4 | port lincoln
# Processing Record 12 of Set 4 | susanville
# Processing Record 13 of Set 4 | guerrero negro
# Processing Record 14 of Set 4 | san rafael
# Processing Record 15 of Set 4 | saint-augustin
# Processing Record 16 of Set 4 | srednekolymsk
# Processing Record 17 of Set 4 | xining
# Processing Record 18 of Set 4 | itarema
# Processing Record 19 of Set 4 | aldan
# Processing Record 20 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 4 | loiza
# Processing Record 22 of Set 4 | franca
# Processing Record 23 of Set 4 | secu
# Processing Record 24 of Set 4 | maun
# Processing Record 25 of Set 4 | zvenyhorodka
# Processing Record 26 of Set 4 | pontivy
# Processing Record 27 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 28 of Set 4 | tura
# Processing Record 29 of Set 4 | celestun
# Processing Record 30 of Set 4 | kahta
# Processing Record 31 of Set 4 | wa
# City not found. Skipping...
# Processing Record 32 of Set 4 | natal
# Processing Record 33 of Set 4 | abha
# Processing Record 34 of Set 4 | qaanaaq
# Processing Record 35 of Set 4 | la ronge
# Processing Record 36 of Set 4 | umarkot
# Processing Record 37 of Set 4 | lazaro cardenas
# Processing Record 38 of Set 4 | pevek
# Processing Record 39 of Set 4 | namtsy
# Processing Record 40 of Set 4 | trud
# Processing Record 41 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 4 | east london
# Processing Record 43 of Set 4 | thinadhoo
# Processing Record 44 of Set 4 | pimenta bueno
# Processing Record 45 of Set 4 | kashi
# Processing Record 46 of Set 4 | naze
# Processing Record 47 of Set 4 | polovinnoye
# Processing Record 48 of Set 4 | gashua
# Processing Record 49 of Set 4 | namatanai
# Processing Record 50 of Set 4 | malanje
# Processing Record 1 of Set 5 | san fernando
# Processing Record 2 of Set 5 | clyde river
# Processing Record 3 of Set 5 | jardim
# Processing Record 4 of Set 5 | north bend
# Processing Record 5 of Set 5 | medea
# Processing Record 6 of Set 5 | peruibe
# Processing Record 7 of Set 5 | yazman
# Processing Record 8 of Set 5 | messina
# Processing Record 9 of Set 5 | lorengau
# Processing Record 10 of Set 5 | casas grandes
# Processing Record 11 of Set 5 | praya
# Processing Record 12 of Set 5 | mayo
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | nikolskoye
# Processing Record 15 of Set 5 | vitim
# Processing Record 16 of Set 5 | ponorogo
# Processing Record 17 of Set 5 | waingapu
# Processing Record 18 of Set 5 | tshikapa
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | roma
# Processing Record 21 of Set 5 | sola
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | aykhal
# Processing Record 24 of Set 5 | faya
# Processing Record 25 of Set 5 | norman wells
# Processing Record 26 of Set 5 | tarpon springs
# Processing Record 27 of Set 5 | luderitz
# Processing Record 28 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 5 | saint-francois
# Processing Record 30 of Set 5 | batticaloa
# Processing Record 31 of Set 5 | singaraja
# Processing Record 32 of Set 5 | san ramon
# Processing Record 33 of Set 5 | qufu
# Processing Record 34 of Set 5 | anopino
# Processing Record 35 of Set 5 | pueblo nuevo
# Processing Record 36 of Set 5 | port elizabeth
# Processing Record 37 of Set 5 | namibe
# Processing Record 38 of Set 5 | bentiu
# Processing Record 39 of Set 5 | namakkal
# Processing Record 40 of Set 5 | bethel
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 5 | riohacha
# Processing Record 44 of Set 5 | khanpur
# Processing Record 45 of Set 5 | san felipe
# Processing Record 46 of Set 5 | cururupu
# Processing Record 47 of Set 5 | roald
# Processing Record 48 of Set 5 | fort smith
# Processing Record 49 of Set 5 | dourbali
# Processing Record 50 of Set 5 | oktyabrskiy
# Processing Record 1 of Set 6 | esmeraldas
# Processing Record 2 of Set 6 | jumla
# Processing Record 3 of Set 6 | ivangorod
# Processing Record 4 of Set 6 | pangody
# Processing Record 5 of Set 6 | les cayes
# Processing Record 6 of Set 6 | lingao
# Processing Record 7 of Set 6 | jilemnice
# Processing Record 8 of Set 6 | muslyumovo
# Processing Record 9 of Set 6 | ancud
# Processing Record 10 of Set 6 | salihorsk
# Processing Record 11 of Set 6 | hobyo
# Processing Record 12 of Set 6 | kavaratti
# Processing Record 13 of Set 6 | san cristobal
# Processing Record 14 of Set 6 | quatre cocos
# Processing Record 15 of Set 6 | topolobampo
# Processing Record 16 of Set 6 | paamiut
# Processing Record 17 of Set 6 | sokolo
# Processing Record 18 of Set 6 | kodiak
# Processing Record 19 of Set 6 | georgetown
# Processing Record 20 of Set 6 | watsa
# Processing Record 21 of Set 6 | sumter
# Processing Record 22 of Set 6 | hajipur
# Processing Record 23 of Set 6 | camiri
# Processing Record 24 of Set 6 | abu samrah
# Processing Record 25 of Set 6 | aliman
# Processing Record 26 of Set 6 | kamaishi
# Processing Record 27 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 28 of Set 6 | casper
# Processing Record 29 of Set 6 | oranjemund
# Processing Record 30 of Set 6 | esso
# Processing Record 31 of Set 6 | sisimiut
# Processing Record 32 of Set 6 | meulaboh
# Processing Record 33 of Set 6 | kartuzy
# Processing Record 34 of Set 6 | college
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | wenling
# Processing Record 37 of Set 6 | tiznit
# Processing Record 38 of Set 6 | buta
# Processing Record 39 of Set 6 | mata grande
# Processing Record 40 of Set 6 | el balyana
# City not found. Skipping...
# Processing Record 41 of Set 6 | sidrolandia
# Processing Record 42 of Set 6 | carnarvon
# Processing Record 43 of Set 6 | llorente
# Processing Record 44 of Set 6 | kieta
# Processing Record 45 of Set 6 | berlevag
# Processing Record 46 of Set 6 | borovoy
# Processing Record 47 of Set 6 | dwarka
# Processing Record 48 of Set 6 | catuday
# Processing Record 49 of Set 6 | baruun-urt
# Processing Record 50 of Set 6 | bakchar
# Processing Record 1 of Set 7 | pleasanton
# Processing Record 2 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 7 | comodoro rivadavia
# Processing Record 4 of Set 7 | boralday
# Processing Record 5 of Set 7 | te anau
# Processing Record 6 of Set 7 | taburao
# City not found. Skipping...
# Processing Record 7 of Set 7 | makubetsu
# Processing Record 8 of Set 7 | alyangula
# Processing Record 9 of Set 7 | asfi
# Processing Record 10 of Set 7 | pignon
# Processing Record 11 of Set 7 | pangnirtung
# Processing Record 12 of Set 7 | bochnia
# Processing Record 13 of Set 7 | los llanos de aridane
# Processing Record 14 of Set 7 | souillac
# Processing Record 15 of Set 7 | kansk
# Processing Record 16 of Set 7 | bandarbeyla
# Processing Record 17 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 18 of Set 7 | conceicao do araguaia
# Processing Record 19 of Set 7 | smithers
# Processing Record 20 of Set 7 | sao filipe
# Processing Record 21 of Set 7 | kloulklubed
# Processing Record 22 of Set 7 | portland
# Processing Record 23 of Set 7 | esperance
# Processing Record 24 of Set 7 | broome
# Processing Record 25 of Set 7 | tamandare
# Processing Record 26 of Set 7 | verkhoyansk
# Processing Record 27 of Set 7 | isabela
# Processing Record 28 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 29 of Set 7 | robertsport
# Processing Record 30 of Set 7 | aripuana
# Processing Record 31 of Set 7 | margate
# Processing Record 32 of Set 7 | muzhi
# Processing Record 33 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 34 of Set 7 | port alfred
# Processing Record 35 of Set 7 | lepley
# Processing Record 36 of Set 7 | thompson
# Processing Record 37 of Set 7 | egvekinot
# Processing Record 38 of Set 7 | ornskoldsvik
# Processing Record 39 of Set 7 | charters towers
# Processing Record 40 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 42 of Set 7 | salalah
# Processing Record 43 of Set 7 | villa carlos paz
# Processing Record 44 of Set 7 | dingle
# Processing Record 45 of Set 7 | waipawa
# Processing Record 46 of Set 7 | maceio
# Processing Record 47 of Set 7 | pyaozerskiy
# Processing Record 48 of Set 7 | lugovoy
# Processing Record 49 of Set 7 | nemuro
# Processing Record 50 of Set 7 | saldanha
# Processing Record 1 of Set 8 | iskateley
# Processing Record 2 of Set 8 | thunder bay
# Processing Record 3 of Set 8 | najran
# Processing Record 4 of Set 8 | eureka
# Processing Record 5 of Set 8 | coihaique
# Processing Record 6 of Set 8 | geraldton
# Processing Record 7 of Set 8 | hauterive
# Processing Record 8 of Set 8 | ryotsu
# Processing Record 9 of Set 8 | kudymkar
# Processing Record 10 of Set 8 | tigil
# Processing Record 11 of Set 8 | moron
# Processing Record 12 of Set 8 | mandan
# Processing Record 13 of Set 8 | leningradskiy
# Processing Record 14 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 8 | pinillos
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 8 | ostersund
# Processing Record 19 of Set 8 | labuhan
# Processing Record 20 of Set 8 | jalu
# Processing Record 21 of Set 8 | faridpur
# Processing Record 22 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 8 | araouane
# Processing Record 24 of Set 8 | pachino
# Processing Record 25 of Set 8 | flin flon
# Processing Record 26 of Set 8 | svetlyy
# Processing Record 27 of Set 8 | port blair
# Processing Record 28 of Set 8 | okha
# Processing Record 29 of Set 8 | mangaratiba
# Processing Record 30 of Set 8 | paracuru
# Processing Record 31 of Set 8 | ginir
# Processing Record 32 of Set 8 | lavrentiya
# Processing Record 33 of Set 8 | bridlington
# Processing Record 34 of Set 8 | bathsheba
# Processing Record 35 of Set 8 | davila
# Processing Record 36 of Set 8 | luanda
# Processing Record 37 of Set 8 | auki
# Processing Record 38 of Set 8 | christchurch
# Processing Record 39 of Set 8 | ukiah
# Processing Record 40 of Set 8 | necochea
# Processing Record 41 of Set 8 | horta
# Processing Record 42 of Set 8 | batemans bay
# Processing Record 43 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 8 | chingirlau
# Processing Record 45 of Set 8 | sorland
# Processing Record 46 of Set 8 | edd
# Processing Record 47 of Set 8 | goderich
# Processing Record 48 of Set 8 | bara
# Processing Record 49 of Set 8 | kenai
# Processing Record 50 of Set 8 | la grande
# Processing Record 1 of Set 9 | kailahun
# Processing Record 2 of Set 9 | litovko
# Processing Record 3 of Set 9 | hokitika
# Processing Record 4 of Set 9 | ahipara
# Processing Record 5 of Set 9 | pitimbu
# Processing Record 6 of Set 9 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 7 of Set 9 | dosso
# Processing Record 8 of Set 9 | ucluelet
# Processing Record 9 of Set 9 | hirara
# Processing Record 10 of Set 9 | brazzaville
# Processing Record 11 of Set 9 | chernyshevskiy
# Processing Record 12 of Set 9 | lawrenceburg
# Processing Record 13 of Set 9 | sunbury
# Processing Record 14 of Set 9 | griffith
# Processing Record 15 of Set 9 | rodrigues alves
# Processing Record 16 of Set 9 | bloomington
# Processing Record 17 of Set 9 | vardo
# Processing Record 18 of Set 9 | coahuayana
# Processing Record 19 of Set 9 | beloha
# Processing Record 20 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 9 | tynda
# Processing Record 22 of Set 9 | kunszentmarton
# Processing Record 23 of Set 9 | misratah
# Processing Record 24 of Set 9 | temiscaming
# Processing Record 25 of Set 9 | sao joao da barra
# Processing Record 26 of Set 9 | tabou
# Processing Record 27 of Set 9 | diamantino
# Processing Record 28 of Set 9 | xghajra
# City not found. Skipping...
# Processing Record 29 of Set 9 | zandvoort
# Processing Record 30 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 31 of Set 9 | la plata
# Processing Record 32 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 9 | zaplyusye
# City not found. Skipping...
# Processing Record 34 of Set 9 | keffi
# Processing Record 35 of Set 9 | touros
# Processing Record 36 of Set 9 | satinka
# Processing Record 37 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 38 of Set 9 | kargasok
# Processing Record 39 of Set 9 | magistralnyy
# Processing Record 40 of Set 9 | benjamin constant
# Processing Record 41 of Set 9 | vung tau
# Processing Record 42 of Set 9 | fairbanks
# Processing Record 43 of Set 9 | menongue
# Processing Record 44 of Set 9 | bubaque
# Processing Record 45 of Set 9 | walvis bay
# Processing Record 46 of Set 9 | isangel
# Processing Record 47 of Set 9 | westlock
# Processing Record 48 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 9 | san quintin
# Processing Record 50 of Set 9 | kuningan
# Processing Record 1 of Set 10 | bonfim
# Processing Record 2 of Set 10 | trinidad
# Processing Record 3 of Set 10 | dakar
# Processing Record 4 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 10 | bassano
# Processing Record 6 of Set 10 | yokadouma
# Processing Record 7 of Set 10 | maniitsoq
# Processing Record 8 of Set 10 | bolshaya murta
# City not found. Skipping...
# Processing Record 9 of Set 10 | udachnyy
# Processing Record 10 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 10 | kortkeros
# Processing Record 12 of Set 10 | semnan
# Processing Record 13 of Set 10 | nizhniy kuranakh
# Processing Record 14 of Set 10 | shitanjing
# Processing Record 15 of Set 10 | dubti
# Processing Record 16 of Set 10 | mount isa
# Processing Record 17 of Set 10 | caravelas
# Processing Record 18 of Set 10 | huarmey
# Processing Record 19 of Set 10 | port keats
# Processing Record 20 of Set 10 | baghdad
# Processing Record 21 of Set 10 | hami
# Processing Record 22 of Set 10 | juegang
# Processing Record 23 of Set 10 | aswan
# Processing Record 24 of Set 10 | gayeri
# Processing Record 25 of Set 10 | ponta do sol
# Processing Record 26 of Set 10 | tapes
# Processing Record 27 of Set 10 | saint-pierre
# Processing Record 28 of Set 10 | powell
# Processing Record 29 of Set 10 | linguere
# Processing Record 30 of Set 10 | mutare
# Processing Record 31 of Set 10 | beroroha
# Processing Record 32 of Set 10 | pokhara
# Processing Record 33 of Set 10 | marsh harbour
# Processing Record 34 of Set 10 | husavik
# Processing Record 35 of Set 10 | valverde del camino
# Processing Record 36 of Set 10 | penzance
# Processing Record 37 of Set 10 | westport
# Processing Record 38 of Set 10 | correntina
# Processing Record 39 of Set 10 | yelyzavethradka
# Processing Record 40 of Set 10 | ilulissat
# Processing Record 41 of Set 10 | sao felix do xingu
# Processing Record 42 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 43 of Set 10 | cabo san lucas
# Processing Record 44 of Set 10 | kulhudhuffushi
# Processing Record 45 of Set 10 | tabulbah
# City not found. Skipping...
# Processing Record 46 of Set 10 | karratha
# Processing Record 47 of Set 10 | salinopolis
# Processing Record 48 of Set 10 | pacifica
# Processing Record 49 of Set 10 | mawlaik
# Processing Record 50 of Set 10 | coffs harbour
# Processing Record 1 of Set 11 | amahai
# Processing Record 2 of Set 11 | mar del plata
# Processing Record 3 of Set 11 | ranong
# Processing Record 4 of Set 11 | pervomayskiy
# Processing Record 5 of Set 11 | ankang
# Processing Record 6 of Set 11 | sorong
# Processing Record 7 of Set 11 | tombouctou
# Processing Record 8 of Set 11 | araxa
# Processing Record 9 of Set 11 | marabba
# Processing Record 10 of Set 11 | shenjiamen
# Processing Record 11 of Set 11 | mecca
# Processing Record 12 of Set 11 | cidreira
# Processing Record 13 of Set 11 | ulaangom
# Processing Record 14 of Set 11 | anshun
# Processing Record 15 of Set 11 | varkaus
# Processing Record 16 of Set 11 | krasnoselkup
# Processing Record 17 of Set 11 | plettenberg bay
# Processing Record 18 of Set 11 | deputatskiy
# Processing Record 19 of Set 11 | verkhovye
# Processing Record 20 of Set 11 | eldoret
# Processing Record 21 of Set 11 | zatoka
# Processing Record 22 of Set 11 | tahta
# Processing Record 23 of Set 11 | porto velho
# Processing Record 24 of Set 11 | hasaki
# Processing Record 25 of Set 11 | ruidoso
# Processing Record 26 of Set 11 | plouzane
# Processing Record 27 of Set 11 | katsuura
# Processing Record 28 of Set 11 | yanji
# Processing Record 29 of Set 11 | sungurlu
# Processing Record 30 of Set 11 | henties bay
# Processing Record 31 of Set 11 | mackenzie
# Processing Record 32 of Set 11 | rantepao
# Processing Record 33 of Set 11 | lower hutt
# Processing Record 34 of Set 11 | cockburn town
# Processing Record 35 of Set 11 | lasa
# Processing Record 36 of Set 11 | zary
# Processing Record 37 of Set 11 | victor harbor
# Processing Record 38 of Set 11 | shimoda
# Processing Record 39 of Set 11 | vicksburg
# Processing Record 40 of Set 11 | umea
# Processing Record 41 of Set 11 | ekhabi
# Processing Record 42 of Set 11 | pinsk
# Processing Record 43 of Set 11 | muyezerskiy
# Processing Record 44 of Set 11 | klyuchi
# Processing Record 45 of Set 11 | windhoek
# Processing Record 46 of Set 11 | kirakira
# Processing Record 47 of Set 11 | richards bay
# Processing Record 48 of Set 11 | kachiry
# Processing Record 49 of Set 11 | padang
# Processing Record 50 of Set 11 | san patricio
# Processing Record 1 of Set 12 | yulara
# Processing Record 2 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 12 | zemio
# Processing Record 4 of Set 12 | havre-saint-pierre
# Processing Record 5 of Set 12 | arrifes
# Processing Record 6 of Set 12 | ogaminana
# Processing Record 7 of Set 12 | canosa di puglia
# Processing Record 8 of Set 12 | oktyabrskoye
# Processing Record 9 of Set 12 | barinas
# Processing Record 10 of Set 12 | wesselsbron
# Processing Record 11 of Set 12 | chapais
# Processing Record 12 of Set 12 | moose factory
# Processing Record 13 of Set 12 | taoudenni
# Processing Record 14 of Set 12 | methoni
# Processing Record 15 of Set 12 | gopalpur
# Processing Record 16 of Set 12 | gravina in puglia
# Processing Record 17 of Set 12 | banda aceh
# Processing Record 18 of Set 12 | zhanakorgan
# Processing Record 19 of Set 12 | sur
# Processing Record 20 of Set 12 | gao
# Processing Record 21 of Set 12 | fort portal
# Processing Record 22 of Set 12 | ballina
# Processing Record 23 of Set 12 | couva
# Processing Record 24 of Set 12 | bandundu
# Processing Record 25 of Set 12 | sharjah
# Processing Record 26 of Set 12 | jertih
# Processing Record 27 of Set 12 | haapu
# City not found. Skipping...
# Processing Record 28 of Set 12 | sambava
# Processing Record 29 of Set 12 | fort nelson
# Processing Record 30 of Set 12 | kigoma
# Processing Record 31 of Set 12 | meadow lake
# Processing Record 32 of Set 12 | pokosnoye
# Processing Record 33 of Set 12 | arecibo
# Processing Record 34 of Set 12 | nizhnyaya tavda
# Processing Record 35 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 12 | longkou
# Processing Record 37 of Set 12 | pathein
# Processing Record 38 of Set 12 | cairns
# Processing Record 39 of Set 12 | navahrudak
# Processing Record 40 of Set 12 | eydhafushi
# Processing Record 41 of Set 12 | awjilah
# Processing Record 42 of Set 12 | el alto
# Processing Record 43 of Set 12 | yekaterinogradskaya
# Processing Record 44 of Set 12 | port-cartier
# Processing Record 45 of Set 12 | avera
# Processing Record 46 of Set 12 | coquimbo
# Processing Record 47 of Set 12 | kupang
# Processing Record 48 of Set 12 | satipo
# Processing Record 49 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 50 of Set 12 | kumluca
# Processing Record 1 of Set 13 | shalyhyne
# Processing Record 2 of Set 13 | sioux lookout
# Processing Record 3 of Set 13 | nome
# Processing Record 4 of Set 13 | mnogovershinnyy
# Processing Record 5 of Set 13 | boras
# Processing Record 6 of Set 13 | aksay
# Processing Record 7 of Set 13 | alexandria
# Processing Record 8 of Set 13 | sabang
# Processing Record 9 of Set 13 | tatarka
# Processing Record 10 of Set 13 | chuy
# Processing Record 11 of Set 13 | chardara
# Processing Record 12 of Set 13 | hofn
# Processing Record 13 of Set 13 | qasigiannguit
# Processing Record 14 of Set 13 | sharan
# Processing Record 15 of Set 13 | gairatganj
# Processing Record 16 of Set 13 | yerbogachen
# Processing Record 17 of Set 13 | arica
# Processing Record 18 of Set 13 | morwa
# Processing Record 19 of Set 13 | biak
# Processing Record 20 of Set 13 | kunming
# Processing Record 21 of Set 13 | antofagasta
# Processing Record 22 of Set 13 | nelson bay
# Processing Record 23 of Set 13 | shreveport
# Processing Record 24 of Set 13 | boundiali
# Processing Record 25 of Set 13 | billings
# Processing Record 26 of Set 13 | magaria
# Processing Record 27 of Set 13 | sibolga
# Processing Record 28 of Set 13 | isla vista
# Processing Record 29 of Set 13 | tautira
# Processing Record 30 of Set 13 | bisert
# Processing Record 31 of Set 13 | rensvik
# Processing Record 32 of Set 13 | mabaruma
# Processing Record 33 of Set 13 | kalaleh
# Processing Record 34 of Set 13 | yumen
# Processing Record 35 of Set 13 | lata
# Processing Record 36 of Set 13 | gurupi
# Processing Record 37 of Set 13 | dranceni sat
# City not found. Skipping...
# Processing Record 38 of Set 13 | narsaq
# Processing Record 39 of Set 13 | yenotayevka
# Processing Record 40 of Set 13 | mmabatho
# Processing Record 41 of Set 13 | kollam
# Processing Record 42 of Set 13 | vila
# Processing Record 43 of Set 13 | staritsa
# Processing Record 44 of Set 13 | bambous virieux
# Processing Record 45 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 13 | tocopilla
# Processing Record 47 of Set 13 | salta
# Processing Record 48 of Set 13 | birao
# Processing Record 49 of Set 13 | melton
# Processing Record 50 of Set 13 | vettavalam
# Processing Record 1 of Set 14 | tomatlan
# Processing Record 2 of Set 14 | nioki
# Processing Record 3 of Set 14 | uchiza
# Processing Record 4 of Set 14 | nyurba
# Processing Record 5 of Set 14 | ransang
# Processing Record 6 of Set 14 | riberalta
# Processing Record 7 of Set 14 | svetlaya
# Processing Record 8 of Set 14 | riyadh
# Processing Record 9 of Set 14 | ouadda
# Processing Record 10 of Set 14 | gwembe
# Processing Record 11 of Set 14 | pudozh
# Processing Record 12 of Set 14 | helong
# Processing Record 13 of Set 14 | shestakovo
# Processing Record 14 of Set 14 | kawanoe
# Processing Record 15 of Set 14 | pskov
# Processing Record 16 of Set 14 | mazagao
# Processing Record 17 of Set 14 | corn island
# Processing Record 18 of Set 14 | suba
# Processing Record 19 of Set 14 | wenatchee
# Processing Record 20 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 21 of Set 14 | sitka
# Processing Record 22 of Set 14 | petropavlovka
# Processing Record 23 of Set 14 | sassandra
# Processing Record 24 of Set 14 | rapar
# Processing Record 25 of Set 14 | godhra
# Processing Record 26 of Set 14 | huazolotitlan
# City not found. Skipping...
# Processing Record 27 of Set 14 | gazojak
# Processing Record 28 of Set 14 | tabasalu
# Processing Record 29 of Set 14 | dunedin
# Processing Record 30 of Set 14 | muros
# Processing Record 31 of Set 14 | ponta delgada
# Processing Record 32 of Set 14 | beringovskiy
# Processing Record 33 of Set 14 | new port richey
# Processing Record 34 of Set 14 | alihe
# Processing Record 35 of Set 14 | sinnamary
# Processing Record 36 of Set 14 | kushima
# Processing Record 37 of Set 14 | matamoros
# Processing Record 38 of Set 14 | estacion coahuila
# Processing Record 39 of Set 14 | buritizeiro
# Processing Record 40 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 14 | vao
# Processing Record 42 of Set 14 | illapel
# Processing Record 43 of Set 14 | baleshwar
# Processing Record 44 of Set 14 | gamba
# Processing Record 45 of Set 14 | bongaree
# Processing Record 46 of Set 14 | conde
# Processing Record 47 of Set 14 | nipawin
# Processing Record 48 of Set 14 | toora-khem
# Processing Record 49 of Set 14 | miri
# Processing Record 50 of Set 14 | atar
# Processing Record 1 of Set 15 | moctezuma
# Processing Record 2 of Set 15 | anzio
# Processing Record 3 of Set 15 | kutum
# Processing Record 4 of Set 15 | korla
# Processing Record 5 of Set 15 | praia da vitoria
# Processing Record 6 of Set 15 | takoradi
# Processing Record 7 of Set 15 | kutulik
# Processing Record 8 of Set 15 | dauriya
# Processing Record 9 of Set 15 | boueni
# Processing Record 10 of Set 15 | asau
# Processing Record 11 of Set 15 | omboue
# Processing Record 12 of Set 15 | adrar
# Processing Record 13 of Set 15 | moree
# Processing Record 14 of Set 15 | nouakchott
# Processing Record 15 of Set 15 | kurumkan
# Processing Record 16 of Set 15 | markdale
# Processing Record 17 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 15 | locri
# Processing Record 19 of Set 15 | ciudad bolivar
# Processing Record 20 of Set 15 | mayumba
# Processing Record 21 of Set 15 | ridgecrest
# Processing Record 22 of Set 15 | byron bay
# Processing Record 23 of Set 15 | uige
# Processing Record 24 of Set 15 | balykshi
# Processing Record 25 of Set 15 | cap malheureux
# Processing Record 26 of Set 15 | xai-xai
# Processing Record 27 of Set 15 | mundo nuevo
# Processing Record 28 of Set 15 | batagay
# Processing Record 29 of Set 15 | kalmunai
# Processing Record 30 of Set 15 | baisha
# Processing Record 31 of Set 15 | taybad
# Processing Record 32 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 15 | parabel
# Processing Record 34 of Set 15 | nandigama
# Processing Record 35 of Set 15 | sabha
# Processing Record 36 of Set 15 | killybegs
# Processing Record 37 of Set 15 | zhigansk
# Processing Record 38 of Set 15 | cavalcante
# Processing Record 39 of Set 15 | emerald
# Processing Record 40 of Set 15 | aksarka
# Processing Record 41 of Set 15 | progress
# Processing Record 42 of Set 15 | tandil
# Processing Record 43 of Set 15 | la palma
# Processing Record 44 of Set 15 | chiredzi
# Processing Record 45 of Set 15 | sfantu gheorghe
# Processing Record 46 of Set 15 | dumraon
# Processing Record 47 of Set 15 | vuktyl
# Processing Record 48 of Set 15 | baiquan
# Processing Record 49 of Set 15 | viedma
# Processing Record 50 of Set 15 | vilhena
# Processing Record 1 of Set 16 | nouadhibou
# Processing Record 2 of Set 16 | requena
# Processing Record 3 of Set 16 | teguldet
# Processing Record 4 of Set 16 | kaduqli
# Processing Record 5 of Set 16 | tongzi
# Processing Record 6 of Set 16 | parambu
# Processing Record 7 of Set 16 | santa ana
# Processing Record 8 of Set 16 | calvinia
# Processing Record 9 of Set 16 | solnechnyy
# Processing Record 10 of Set 16 | sao miguel do araguaia
# Processing Record 11 of Set 16 | flers
# Processing Record 12 of Set 16 | castanos
# Processing Record 13 of Set 16 | sumenep
# Processing Record 14 of Set 16 | zeya
# Processing Record 15 of Set 16 | bangassou
# Processing Record 16 of Set 16 | katangli
# Processing Record 17 of Set 16 | ambodifototra
# City not found. Skipping...
# Processing Record 18 of Set 16 | ostrovnoy
# Processing Record 19 of Set 16 | arman
# Processing Record 20 of Set 16 | oistins
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 711

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Anchorage  61.2181 -149.9003     23.00        68           1
# 1         Seoul  37.5683  126.9778     32.00        64           0
# 2         Ullal  12.8000   74.8500     75.20        83           0
# 3  Port Moresby  -9.4431  147.1797     75.20        94          75
# 4    Chokurdakh  70.6333  147.9167    -29.79        85          41
# 5       Rikitea -23.1203 -134.9692     79.57        70           0
# 6  Rio Gallegos -51.6226  -69.2181     62.60        34           0
# 7     Cape Town -33.9258   18.4232     71.01        77          75
# 8   Yellowknife  62.4560 -114.3525    -11.99        77          20
# 9       Chimore -16.9833  -65.1333     74.23        95         100
#
#    Wind Speed Country Current Description
# 0        5.75      US           clear sky
# 1        8.05      KR           clear sky
# 2        5.75      IN                mist
# 3       10.36      PG       moderate rain
# 4        8.23      RU    scattered clouds
# 5       10.74      PF           clear sky
# 6       16.11      AR           clear sky
# 7        5.75      ZA       broken clouds
# 8        4.61      CA          few clouds
# 9        1.63      BO     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Anchorage      US  61.2181 -149.9003     23.00        68           1
# 1         Seoul      KR  37.5683  126.9778     32.00        64           0
# 2         Ullal      IN  12.8000   74.8500     75.20        83           0
# 3  Port Moresby      PG  -9.4431  147.1797     75.20        94          75
# 4    Chokurdakh      RU  70.6333  147.9167    -29.79        85          41
# 5       Rikitea      PF -23.1203 -134.9692     79.57        70           0
# 6  Rio Gallegos      AR -51.6226  -69.2181     62.60        34           0
# 7     Cape Town      ZA -33.9258   18.4232     71.01        77          75
# 8   Yellowknife      CA  62.4560 -114.3525    -11.99        77          20
# 9       Chimore      BO -16.9833  -65.1333     74.23        95         100
#
#    Wind Speed Current Description
# 0        5.75           clear sky
# 1        8.05           clear sky
# 2        5.75                mist
# 3       10.36       moderate rain
# 4        8.23    scattered clouds
# 5       10.74           clear sky
# 6       16.11           clear sky
# 7        5.75       broken clouds
# 8        4.61          few clouds
# 9        1.63     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
